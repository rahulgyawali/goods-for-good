# %%
import pandas as pd

# %%
df = pd.read_excel('./Zip_Locale_Detail.xls', engine = 'xlrd')
set(df['PHYSICAL STATE'])
# Out:
# {'AK',
#  'AL',
#  'AR',
#  'AS',
#  'AZ',
#  'CA',
#  'CO',
#  'CT',
#  'DC',
#  'DE',
#  'FL',
#  'FM',
#  'GA',
#  'GU',
#  'HI',
#  'IA',
#  'ID',
#  'IL',
#  'IN',
#  'KS',
#  'KY',
#  'LA',
#  'MA',
#  'MD',
#  'ME',
#  'MH',
#  'MI',
#  'MN',
#  'MO',
#  'MP',
#  'MS',
#  'MT',
#  'NC',
#  'ND',
#  'NE',
#  'NH',
#  'NJ',
#  'NM',
#  'NV',
#  'NY',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'PR',
#  'PW',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'UT',
#  'VA',
#  'VI',
#  'VT',
#  'WA',
#  'WI',
#  'WV',
#  'WY'}

# %%
state_abbreviations = {
    'AK': 'Alaska',
    'AL': 'Alabama',
    'AR': 'Arkansas',
    'AS': 'American Samoa',
    'AZ': 'Arizona',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DC': 'District of Columbia',
    'DE': 'Delaware',
    'FL': 'Florida',
    'FM': 'Federated States of Micronesia',
    'GA': 'Georgia',
    'GU': 'Guam',
    'HI': 'Hawaii',
    'IA': 'Iowa',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'MA': 'Massachusetts',
    'MD': 'Maryland',
    'ME': 'Maine',
    'MH': 'Marshall Islands',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MO': 'Missouri',
    'MP': 'Northern Mariana Islands',
    'MS': 'Mississippi',
    'MT': 'Montana',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'NE': 'Nebraska',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NV': 'Nevada',
    'NY': 'New York',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'PR': 'Puerto Rico',
    'PW': 'Palau',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VA': 'Virginia',
    'VI': 'U.S. Virgin Islands',
    'VT': 'Vermont',
    'WA': 'Washington',
    'WI': 'Wisconsin',
    'WV': 'West Virginia',
    'WY': 'Wyoming'
}

# %%
set_of_seen = set()
rows=[]
for i, row in df.iterrows():
    state_abbr = row['PHYSICAL STATE']
    if state_abbr in set_of_seen:
        continue
    try:
        state = state_abbreviations[state_abbr]
        row['State'] = state
        rows.append(row)
        # print(row)
        set_of_seen.add(state_abbr)
    except:
        print(state_abbr)
        set_of_seen.add(state_abbr)
        pass

unique_df = pd.DataFrame(rows)
print(unique_df)
# Out:
#       AREA NAME AREA CODE   DISTRICT NAME  DISTRICT NO  DELIVERY ZIPCODE  \
# 0      SOUTHERN        4G     PUERTO RICO            6               601
# 119    SOUTHERN        4G     PUERTO RICO            6               801
# 206    ATLANTIC        4B           MA-RI           20              1001
# 1015   ATLANTIC        4B           MA-RI           20              2801
# 1120   ATLANTIC        4B        ME-NH-VT           40              3031
# 1434   ATLANTIC        4B        ME-NH-VT           40              3901
# 1965   ATLANTIC        4B        ME-NH-VT           40              5001
# 2300   ATLANTIC        4B     CONNECTICUT           60              6001
# 2525   ATLANTIC        4B     CONNECTICUT           60              6390
# 2766   ATLANTIC        4B      NEW JERSEY           70              7001
# 6048   ATLANTIC        4B  PENNSYLVANIA 1          150             15001
# 8419   ATLANTIC        4B         DE-PA 2          190             19701
# 8503   ATLANTIC        4B         DE-PA 2          190             19964
# 8520   ATLANTIC        4B        MARYLAND          200             20001
# 8570   ATLANTIC        4B        MARYLAND          200             20041
# 10255  ATLANTIC        4B        VIRGINIA          230             24131
# 11489  ATLANTIC        4B  NORTH CAROLINA          270             27006
# 12661  SOUTHERN        4G  SOUTH CAROLINA          290             29001
# 13236  SOUTHERN        4G         GEORGIA          300             30002
# 13801  SOUTHERN        4G         GEORGIA          300             30750
# 14233  SOUTHERN        4G       FLORIDA 1          320             32003
# 15711  SOUTHERN        4G           AL-MS          350             35004
# 17142   CENTRAL        4J           KY-WV          400             38257
# 17328  SOUTHERN        4G           AL-MS          350             38601
# 19005   CENTRAL        4J          OHIO 2          450             43001
# 20294   CENTRAL        4J          OHIO 2          450             45390
# 21662   CENTRAL        4J      MICHIGAN 1          481             48001
# 22952   CENTRAL        4J        IA-NE-SD          500             50001
# 23652   CENTRAL        4J        IA-NE-SD          500             51510
# 24139   CENTRAL        4J       WISCONSIN          530             53001
# 25132   CENTRAL        4J           MN-ND          553             55001
# 26023   CENTRAL        4J           MN-ND          553             56520
# 26207   CENTRAL        4J        IA-NE-SD          500             57001
# 27140   WESTPAC        4E        ID-MT-OR          970             59001
# 27549   CENTRAL        4J      ILLINOIS 1          606             60002
# 29287   CENTRAL        4J           KS-MO          630             63005
# 30731   CENTRAL        4J           KS-MO          630             66002
# 32350  SOUTHERN        4G       LOUISIANA          700             70001
# 33064  SOUTHERN        4G           AR-OK          730             71601
# 33176  SOUTHERN        4G         TEXAS 1          752             71854
# 33822  SOUTHERN        4G           AR-OK          730             73001
# 37127   WESTPAC        4E           AZ-NM          852             79821
# 37199   WESTPAC        4E           CO-WY          800             80001
# 37841   WESTPAC        4E           CO-WY          800             82001
# 38043   WESTPAC        4E        ID-MT-OR          970             83201
# 38308   WESTPAC        4E        ID-MT-OR          970             83822
# 38363   WESTPAC        4E           NV-UT          890             84001
# 38710   WESTPAC        4E           NV-UT          890             84784
# 39646   WESTPAC        4E           NV-UT          890             89001
# 39877   WESTPAC        4E    CALIFORNIA 5          900             90001
# 42468   WESTPAC        4E          HAWAII          967             96701
# 42566   WESTPAC        4E          HAWAII          967             96799
# 42599   WESTPAC        4E          HAWAII          967             96910
# 42615   WESTPAC        4E          HAWAII          967             96940
# 42616   WESTPAC        4E          HAWAII          967             96941
# 42620   WESTPAC        4E          HAWAII          967             96950
# 42626   WESTPAC        4E          HAWAII          967             96960
# 42628   WESTPAC        4E        ID-MT-OR          970             97001
# 43915   WESTPAC        4E          ALASKA          995             99501
#
#                    LOCALE NAME             PHYSICAL DELV ADDR  \
# 0                     ADJUNTAS          37 CALLE MUNOZ RIVERA
# 119           CHARLOTTE AMALIE             9846 ESTATE THOMAS
# 206                     AGAWAM                600 SUFFIELD ST
# 1015                ADAMSVILLE                70A CRANDALL RD
# 1120                   AMHERST    199 STATE ROUTE 101 UNIT 4D
# 1434                   BERWICK                   43 ROUTE 236
# 1965               LYMAN DPOBU                   27 S MAIN ST
# 2300                      AVON                   15 ENFORD ST
# 2525            FISHERS ISLAND                 1 ORIENTAL AVE
# 2766                    AVENEL                1065 RAHWAY AVE
# 6048                 ALIQUIPPA               517 FRANKLIN AVE
# 8419                      BEAR                125 RICKEY BLVD
# 8503                   MARYDEL                114 HALLTOWN RD
# 8520             LE DROIT PARK             416 FLORIDA AVE NW
# 8570                    DULLES      45005 AVIATION DR STE 120
# 10255                GAP MILLS  11331 SWEET SPRINGS VALLEY RD
# 11489                  ADVANCE          1860 NC HIGHWAY 801 S
# 12661                   ALCOLU                   1842 MAIN ST
# 13236         AVONDALE ESTATES                 15 FRANKLIN ST
# 13801         LOOKOUT MOUNTAIN                 824 SCENIC HWY
# 14233                RIDGEWOOD                 225 COLLEGE DR
# 15711                    MOODY                2455 MOODY PKWY
# 17142                   FULTON                  416 WALNUT ST
# 17328                ABBEVILLE                    8 E LONG ST
# 19005               ALEXANDRIA                    2 W MAIN ST
# 20294               UNION CITY                 102 W PEARL ST
# 21662                  ALGONAC       801 SAINT CLAIR RIVER DR
# 22952                     MILO                    105 MAIN ST
# 23652              AMES AVENUE              3030 MEREDITH AVE
# 24139                    ADELL                  611 MAINE AVE
# 25132                    AFTON         3121 SAINT CROIX TRL S
# 26023                 WAHPETON                  926 2ND AVE N
# 26207                 ALCESTER                  111 DAKOTA ST
# 27140                ABSAROKEE               25 N MONTANA AVE
# 27549                  ANTIOCH                 420 ORCHARD ST
# 29287             CHESTERFIELD        16105 SWINGLEY RIDGE RD
# 30731                 ATCHISON                 621 KANSAS AVE
# 32350           JOHNSON STREET                3517 JOHNSON ST
# 33064               PINE BLUFF          100 E 8TH AVE STE 105
# 33176                TEXARKANA              2211 N ROBISON RD
# 33822                   ALBERT        22180 STATE HIGHWAY 146
# 37127                  ANTHONY                1190 ANTHONY DR
# 37199                   ARVADA                5885 ALLISON ST
# 37841                 CHEYENNE              4800 CONVERSE AVE
# 38043                POCATELLO                 730 E CLARK ST
# 38308                  NEWPORT           100 N WASHINGTON AVE
# 38363                 ALTAMONT                 15537 W 4000 N
# 38710            COLORADO CITY                85 S CENTRAL ST
# 39646                    ALAMO           40 N PURPLE SAGE AVE
# 39877  MAIN OFFICE LOS ANGELES             7101 S CENTRAL AVE
# 42468                     AIEA              99-040 KAUHALE ST
# 42566                PAGO PAGO                 1 LUMANAI BLDG
# 42599                BARRIGADA                    489 ARMY DR
# 42615                    PALAU                        1 PALAU
# 42616                  POHNPEI                 1 KOLONIA TOWN
# 42620         CPU CAPITOL HILL                   1 CAPITOL HL
# 42626                   MAJURO                   1 ULIGA TOWN
# 42628                 ANTELOPE                  45404 MAIN ST
# 43915              EASTCHESTER                   800 INGRA ST
#
#               PHYSICAL CITY PHYSICAL STATE  PHYSICAL ZIP  PHYSICAL ZIP 4  \
# 0                  ADJUNTAS             PR           601          9998.0
# 119               ST THOMAS             VI           802          9998.0
# 206                  AGAWAM             MA          1001          9998.0
# 1015             ADAMSVILLE             RI          2801          9800.0
# 1120                AMHERST             NH          3031          9998.0
# 1434                BERWICK             ME          3901          9998.0
# 1965   WHITE RIVER JUNCTION             VT          5001          9995.0
# 2300                   AVON             CT          6001          9998.0
# 2525         FISHERS ISLAND             NY          6390          9992.0
# 2766                 AVENEL             NJ          7001          9998.0
# 6048              ALIQUIPPA             PA         15001          9998.0
# 8419                   BEAR             DE         19701          9998.0
# 8503                MARYDEL             MD         21649          9998.0
# 8520             WASHINGTON             DC         20001          9997.0
# 8570               STERLING             VA         20166          7533.0
# 10255             GAP MILLS             WV         24941          5000.0
# 11489               ADVANCE             NC         27006          9998.0
# 12661                ALCOLU             SC         29001          8812.0
# 13236      AVONDALE ESTATES             GA         30002          9998.0
# 13801      LOOKOUT MOUNTAIN             TN         37350          9998.0
# 14233           ORANGE PARK             FL         32065          9998.0
# 15711                 MOODY             AL         35004          1600.0
# 17142                FULTON             KY         42041          9998.0
# 17328             ABBEVILLE             MS         38601          9998.0
# 19005            ALEXANDRIA             OH         43001          9622.0
# 20294            UNION CITY             IN         47390          9998.0
# 21662               ALGONAC             MI         48001          9998.0
# 22952                  MILO             IA         50166          7700.0
# 23652                 OMAHA             NE         68111          9998.0
# 24139                 ADELL             WI         53001          9800.0
# 25132                 AFTON             MN         55001          9419.0
# 26023              WAHPETON             ND         58075          9998.0
# 26207              ALCESTER             SD         57001          9998.0
# 27140             ABSAROKEE             MT         59001          9998.0
# 27549               ANTIOCH             IL         60002          3135.0
# 29287          CHESTERFIELD             MO         63017          9998.0
# 30731              ATCHISON             KS         66002          9998.0
# 32350              METAIRIE             LA         70001          5100.0
# 33064            PINE BLUFF             AR         71601          9998.0
# 33176             TEXARKANA             TX         75501          9998.0
# 33822                ALBERT             OK         73001          9998.0
# 37127               ANTHONY             NM         88021          9800.0
# 37199                ARVADA             CO         80004          9998.0
# 37841              CHEYENNE             WY         82009          9998.0
# 38043             POCATELLO             ID         83201          9998.0
# 38308               NEWPORT             WA         99156          9998.0
# 38363              ALTAMONT             UT         84001          8000.0
# 38710         COLORADO CITY             AZ         86021          6325.0
# 39646                 ALAMO             NV         89001          9801.0
# 39877           LOS ANGELES             CA         90001          9998.0
# 42468                  AIEA             HI         96701          9998.0
# 42566             PAGO PAGO             AS         96799          9994.0
# 42599             BARRIGADA             GU         96913          9998.0
# 42615                 KOROR             PW         96940          9997.0
# 42616               POHNPEI             FM         96941          9997.0
# 42620                SAIPAN             MP         96950          9997.0
# 42626                MAJURO             MH         96960          9997.0
# 42628              ANTELOPE             OR         97001          7001.0
# 43915             ANCHORAGE             AK         99501          9998.0
#
#                                 State
# 0                         Puerto Rico
# 119               U.S. Virgin Islands
# 206                     Massachusetts
# 1015                     Rhode Island
# 1120                    New Hampshire
# 1434                            Maine
# 1965                          Vermont
# 2300                      Connecticut
# 2525                         New York
# 2766                       New Jersey
# 6048                     Pennsylvania
# 8419                         Delaware
# 8503                         Maryland
# 8520             District of Columbia
# 8570                         Virginia
# 10255                   West Virginia
# 11489                  North Carolina
# 12661                  South Carolina
# 13236                         Georgia
# 13801                       Tennessee
# 14233                         Florida
# 15711                         Alabama
# 17142                        Kentucky
# 17328                     Mississippi
# 19005                            Ohio
# 20294                         Indiana
# 21662                        Michigan
# 22952                            Iowa
# 23652                        Nebraska
# 24139                       Wisconsin
# 25132                       Minnesota
# 26023                    North Dakota
# 26207                    South Dakota
# 27140                         Montana
# 27549                        Illinois
# 29287                        Missouri
# 30731                          Kansas
# 32350                       Louisiana
# 33064                        Arkansas
# 33176                           Texas
# 33822                        Oklahoma
# 37127                      New Mexico
# 37199                        Colorado
# 37841                         Wyoming
# 38043                           Idaho
# 38308                      Washington
# 38363                            Utah
# 38710                         Arizona
# 39646                          Nevada
# 39877                      California
# 42468                          Hawaii
# 42566                  American Samoa
# 42599                            Guam
# 42615                           Palau
# 42616  Federated States of Micronesia
# 42620        Northern Mariana Islands
# 42626                Marshall Islands
# 42628                          Oregon
# 43915                          Alaska

# %%
unique_df.to_csv('usps_zip.csv', index = False)

# %%
set(state_abbreviations.values()) - set(unique_df['State'])
# Out:
# set()

# %%
# Out:
# {'Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming'}

# %%
df_campaigns = pd.read_csv('details_c.csv', usecols =['event_type'])
set(df_campaigns['event_type'])
# Out:
# {'Coastal Flood',
#  'Debris Flow',
#  'Drought',
#  'Dust Storm',
#  'Excessive Heat',
#  'Flash Flood',
#  'Flood',
#  'Funnel Cloud',
#  'Hail',
#  'Heat',
#  'Heavy Rain',
#  'High Surf',
#  'High Wind',
#  'Lightning',
#  'Marine Hail',
#  'Marine Thunderstorm Wind',
#  'Marine Tropical Depression',
#  'Marine Tropical Storm',
#  'Rip Current',
#  'Storm Surge/Tide',
#  'Strong Wind',
#  'Thunderstorm Wind',
#  'Tornado',
#  'Tropical Depression',
#  'Tropical Storm',
#  'Waterspout',
#  'Wildfire'}
